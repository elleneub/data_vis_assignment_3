# %%
import pandas as pd

# Import population estimates as a data frame.
df = pd.read_csv("Unemployment/Unemployment Med HH Inc -Table 1.csv", skiprows=7)

# %%
# Preview the data frame.
df.head()
# Out:
#    FIPStxt State           Area_name Rural_urban_continuum_code_2003  \
# 0     1000    AL             Alabama
# 1     1001    AL  Autauga County, AL                               2
# 2     1003    AL  Baldwin County, AL                               4
# 3     1005    AL  Barbour County, AL                               6
# 4     1007    AL     Bibb County, AL                               1
#
#   Urban_influence_code_2003 Rural_urban_continuum_code_2013  \
# 0
# 1                         2                               2
# 2                         5                               3
# 3                         6                               6
# 4                         1                               1
#
#   Urban_influence_code_2013 Civilian_labor_force_2007 Employed_2007  \
# 0                                           2,175,612     2,089,127
# 1                         2                    24,383        23,577
# ...

# %%
# Check type of FIPStxt
type(df['FIPStxt'][0])
# Out:
# numpy.int64

# %%
# We only want the rows corresponding to states themselves, which all have multiples of 1000 as FIPS.
# Run a filter to check if the FIPStxt%1000 is 0 on preview.
df.head(100).loc[df['FIPStxt']%1000 == 0]
# Out:
#     FIPStxt State Area_name Rural_urban_continuum_code_2003  \
# 0      1000    AL   Alabama
# 68     2000    AK    Alaska
#
#    Urban_influence_code_2003 Rural_urban_continuum_code_2013  \
# 0
# 68
#
#    Urban_influence_code_2013 Civilian_labor_force_2007 Employed_2007  \
# 0                                            2,175,612     2,089,127
# 68                                             350,785       328,579
#
#    Unemployed_2007                    ...                     \
# 0           86,485                    ...
# 68          22,206                    ...
#
#    Civilian_labor_force_2014 Employed_2014 Unemployed_2014  \
# 0                  2,161,313     2,014,284         147,029
# 68                   365,890       340,804          25,086
#
#    Unemployment_rate_2014 Civilian_labor_force_2015 Employed_2015  \
# 0                     6.8                 2,146,157     2,015,189
# 68                    6.9                   363,822       340,227
#
# ...

# %%
# Run the same filter on the full data frame.
states = df.loc[df['FIPStxt']%1000 == 0]

# %%
# This is pretty close, but we also included Puerto Rico
states
# Out:
#       FIPStxt State             Area_name Rural_urban_continuum_code_2003  \
# 0        1000    AL               Alabama
# 68       2000    AK                Alaska
# 101      4000    AZ               Arizona
# 117      5000    AR              Arkansas
# 193      6000    CA            California
# 252      8000    CO              Colorado
# 317      9000    CT           Connecticut
# 326     10000    DE              Delaware
# 330     11000    DC  District of Columbia
# 332     12000    FL               Florida
# 400     13000    GA               Georgia
# 560     15000    HI                Hawaii
# 565     16000    ID                 Idaho
# 610     17000    IL              Illinois
# 713     18000    IN               Indiana
# 806     19000    IA                  Iowa
# 906     20000    KS                Kansas
# 1012    21000    KY              Kentucky
# 1133    22000    LA             Louisiana
# 1198    23000    ME                 Maine
# ...

# %%
# It's crude, but let's just forcibly it.
states = states.loc[df['FIPStxt'] != 72000]

# %%
# Including headers, this should be 51.
len(states)
# Out:
# 51

# %%
states
# Out:
#       FIPStxt State             Area_name Rural_urban_continuum_code_2003  \
# 0        1000    AL               Alabama
# 68       2000    AK                Alaska
# 101      4000    AZ               Arizona
# 117      5000    AR              Arkansas
# 193      6000    CA            California
# 252      8000    CO              Colorado
# 317      9000    CT           Connecticut
# 326     10000    DE              Delaware
# 330     11000    DC  District of Columbia
# 332     12000    FL               Florida
# 400     13000    GA               Georgia
# 560     15000    HI                Hawaii
# 565     16000    ID                 Idaho
# 610     17000    IL              Illinois
# 713     18000    IN               Indiana
# 806     19000    IA                  Iowa
# 906     20000    KS                Kansas
# 1012    21000    KY              Kentucky
# 1133    22000    LA             Louisiana
# 1198    23000    ME                 Maine
# ...

# %%
states.to_csv("states_unemployment.csv")
