# %%
import pandas as pd

pop = pd.read_csv("states_population.csv")
unem = pd.read_csv("states_unemployment.csv")

# %%
pop
# Out:
#     Unnamed: 0   FIPS State             Area_Name  \
# 0            1   1000    AL               Alabama
# 1           69   2000    AK                Alaska
# 2           99   4000    AZ               Arizona
# 3          115   5000    AR              Arkansas
# 4          191   6000    CA            California
# 5          250   8000    CO              Colorado
# 6          315   9000    CT           Connecticut
# 7          324  10000    DE              Delaware
# 8          328  11000    DC  District of Columbia
# 9          330  12000    FL               Florida
# 10         398  13000    GA               Georgia
# 11         558  15000    HI                Hawaii
# 12         564  16000    ID                 Idaho
# 13         609  17000    IL              Illinois
# 14         712  18000    IN               Indiana
# 15         805  19000    IA                  Iowa
# 16         905  20000    KS                Kansas
# 17        1011  21000    KY              Kentucky
# ...

# %%
unem
# Out:
#     Unnamed: 0  FIPStxt State             Area_name  \
# 0            0     1000    AL               Alabama
# 1           68     2000    AK                Alaska
# 2          101     4000    AZ               Arizona
# 3          117     5000    AR              Arkansas
# 4          193     6000    CA            California
# 5          252     8000    CO              Colorado
# 6          317     9000    CT           Connecticut
# 7          326    10000    DE              Delaware
# 8          330    11000    DC  District of Columbia
# 9          332    12000    FL               Florida
# 10         400    13000    GA               Georgia
# 11         560    15000    HI                Hawaii
# 12         565    16000    ID                 Idaho
# 13         610    17000    IL              Illinois
# 14         713    18000    IN               Indiana
# 15         806    19000    IA                  Iowa
# 16         906    20000    KS                Kansas
# ...

# %%
merged = pop.merge(unem, left_on='FIPS', right_on='FIPStxt', how='outer')

# %%
merged.head()
# Out:
#    Unnamed: 0_x  FIPS State_x   Area_Name  Rural-urban_Continuum Code_2003  \
# 0             1  1000      AL     Alabama                              NaN
# 1            69  2000      AK      Alaska                              NaN
# 2            99  4000      AZ     Arizona                              NaN
# 3           115  5000      AR    Arkansas                              NaN
# 4           191  6000      CA  California                              NaN
#
#    Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
#
#    Urban_Influence_Code_2013  Economic_typology_2015 CENSUS_2010_POP  \
# ...

# %%
merged.to_csv("states_population_unemployment.csv")
